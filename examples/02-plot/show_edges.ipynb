# %%
# %matplotlib inline

# %% [markdown]
# Show Edges {#show_edges_example}
# ==========
#
# Show the edges of all geometries within a mesh.
#
# Uses the `~pyvista.Property.show_edges`{.interpreted-text role="attr"}
# property.

# %% [markdown]
# Sometimes it can be useful to show all of the edges of a mesh when
# rendering to communicate aspects of the dataset like resolution.
#
# Showing the edges for any rendered dataset is as simple as specifying
# the `show_edges` keyword argument to `True` when plotting a dataset.

# %%
from pyvista import examples

cow = examples.download_cow()

cow.plot(show_edges=True, color=True, cpos='xy')

# %% [markdown]
# ::: {.tags}
# plot
# :::
