# %%
# %matplotlib inline

# %% [markdown]
# Clearing a Mesh or the Entire Plot {#clear_example}
# ==================================
#
# Remove elements from a scene using
# `~pyvista.Plotter.clear`{.interpreted-text role="meth"}.

# %%
import pyvista as pv

# %%
pl = pv.Plotter()
actor = pl.add_mesh(pv.Sphere())
pl.remove_actor(actor)
pl.show()

# %% [markdown]
# Clearing the entire plotting window:

# %%
pl = pv.Plotter()
pl.add_mesh(pv.Sphere())
pl.add_mesh(pv.Plane())
pl.clear()  # clears all actors
pl.show()

# %% [markdown]
# Or you can give any actor a `name` when adding it and if an actor is
# added with that same name at a later time, it will replace the previous
# actor:

# %%
pl = pv.Plotter()
pl.add_mesh(pv.Sphere(), name='mymesh')
pl.add_mesh(pv.Plane(), name='mymesh')
# Only the Plane is shown.
pl.show()

# %% [markdown]
# ::: {.tags}
# plot
# :::
